# %% [markdown]
# <a href="https://colab.research.google.com/github/123ujwal/123ujwal_Global_Terrorism_Analysis/blob/main/UJWAL_Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project** **Title** - **Global** **Terrorism** **Analysis**
#
# ![image.png](data:image/png;base64,...)
#
# The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
#
# ##**Characteristics** **of** **the** **Database**
#
# 1. Contains information on over 180,000 terrorist attacks
#
# 2. Currently the most comprehensive unclassified database on terrorist attacks in the world
#
# 3. Includes information on more than 88,000 bombings, 19,000 assassinations, and 11,000 kidnappings since 1970
#
# 4. Includes information on at least 45 variables for each case, with more recent incidents including information on more than 120 variables
#
# 5. More than 4,000,000 news articles and 25,000 news sources were reviewed to collect incident data from 1998 to 2017 alone
#
# ##**Project goals**
#
# 1. Read the source and do some quick research to understand more about the dataset and its topic
#
# 2. Clean the data
#
# 3. Perform Exploratory Data Analysis on the dataset
#
# 4. Analyze the data more deeply and extract insights
# Visualize analysis
# 5.Visualization of the data

# %% [markdown]
# #**Data** **Insights**
#
# Year -> This field contains the year in which the incident occurred.
#
# Month -> This field contains the number of the month in which the incident occurred.
#
# Day -> This field contains the numeric day of the month on which the incident occurred.
#
# Extended -> 1 = "Yes" The duration of an incident extended more than 24 hours. 0 = "No" The duration of an incident extended less
#
# Country -> This field identifies the country or location where the incident occurred.
#
# Region -> This field identifies the region in which the incident occurred.
#
# City -> Name of the city, village, or town in which the incident occurred
#
# Success -> Success of a terrorist strike
#
# Suicide -> 1 = "Yes" The incident was a suicide attack. 0 = "No" There is no indication that the incident was a suicide
#
# Attack_Type -> The general method of attack and broad class of tactics used.
#
# Target_Type -> The general type of target/victim
#
# Target_Sub_Type -> The more specific target category
#
# Attack_Group -> The name of the group that carried out the attack
#
# Weapon -> General type of weapon used in the incident
#
# Number_of_Killed -> The number of total confirmed fatalities for the incident

# %% [markdown]
# ##Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ##Importing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone project/Global Terrorism Data/Global Terrorism Data.csv', encoding="latin1")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Extracting the first five rows from dataframe
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# Extracting the last five rows from dataframe
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ##Data pre-processing:

# %%
#Shape of the dataframe
df.shape
# Out:
# (181691, 135)

# %%
#columns of the dataframe 
df.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#Renaming the columns
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State','region_txt':'Region','attacktype1_txt':'Attack_type','target1':'Target','nkill':'killed','nwound':'Wounded','gname':'Group','weaptype1_txt':'Weapon_type','latitude':'Latitude','longitude':'Longitude','city':'City','targettype1_txt':'Target_type'},inplace=True)

# %%
#Creating a DataFrame with necessary columns only
terr_df=df[['Year','Month','Day','Country','State','Region','Attack_type','Target','killed','Wounded','Group','Weapon_type','Latitude','Longitude','City']]

# %%
for i in terr_df.columns:
  print(i,terr_df[i].nunique())
# Out:
# Year 47
# Month 13
# Day 32
# Country 205
# State 2855
# Region 12
# Attack_type 9
# Target 86006
# killed 205
# Wounded 238
# Group 3537
# Weapon_type 12
# Latitude 48322
# Longitude 48039
# City 36674

# %%
print(f'''
    There are {terr_df.Country.nunique()} countries from {terr_df.Region.nunique()} Regions covered in the data set and consists of terrorist attack of data in {terr_df.Year.nunique()} 
    years from {terr_df.Year.min()} to {terr_df.Year.max()} overall {terr_df.index.nunique()} terrorist attacks are recorded here which 
    consisted about {int(terr_df.killed.sum())} kills and {int(terr_df.Wounded.sum())} wounded
    ''')
# Out:
#     There are 205 countries from 12 Regions covered in the data set and consists of terrorist attack of data in 47
#     years from 1970 to 2017 overall 181691 terrorist attacks are recorded here which
#     consisted about 411868 kills and 523868 wounded

# %%
print('Maximum number of people were killed by a single terrorist attack are',df['nkill'].max(),' that took place in', df['country_txt'].value_counts().idxmax())
# Out:
# Maximum number of people were killed by a single terrorist attack are 1570.0  that took place in Iraq

# %% [markdown]
# ###Null Value Treatment

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#Finding out percentage of NaN values in the dataframe
null_df=(((df.isnull().sum()).sum())/df.size)*100
null_df
print(f'There are {null_df}% of null values in the dataset')
# Out:
# There are 56.481718962414206% of null values in the dataset

# %%
terr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   Attack_type  181691 non-null  object
#  7   Target       181055 non-null  object
#  8   killed       171378 non-null  float64
#  9   Wounded      165380 non-null  float64
#  10  Group        181691 non-null  object
#  11  Weapon_type  181691 non-null  object
#  12  Latitude     177135 non-null  float64
#  13  Longitude    177134 non-null  float64
#  14  City         181257 non-null  object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 20.8+ MB

# %%
#Using fillna() to fill the null values
terr_df['Wounded']=terr_df['Wounded'].fillna(0).astype(int)
terr_df['killed']=terr_df['killed'].fillna(0).astype(int)
terr_df['Latitude']=terr_df['Latitude'].fillna(0).astype(int)
terr_df['Longitude']=terr_df['Longitude'].fillna(0).astype(int)

# %%
terr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   Attack_type  181691 non-null  object
#  7   Target       181055 non-null  object
#  8   killed       181691 non-null  int64
#  9   Wounded      181691 non-null  int64
#  10  Group        181691 non-null  object
#  11  Weapon_type  181691 non-null  object
#  12  Latitude     181691 non-null  int64
#  13  Longitude    181691 non-null  int64
#  14  City         181257 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 20.8+ MB

# %%
new_null_df=(((terr_df.isnull().sum()).sum())/terr_df.size)*100
new_null_df
print(f'There are {new_null_df}% of null values in the dataset after filling the null values ')
# Out:
# There are 0.05470826843376942% of null values in the dataset after filling the null values

# %% [markdown]
# ###Heat Map to Determine the corelation between variables

# %%
terr_df.corr()
# Out:
#                Year     Month       Day    killed   Wounded  Latitude  \
# Year       1.000000  0.000139  0.018254  0.021252  0.017484  0.184924
# Month      0.000139  1.000000  0.005497  0.004031  0.003178 -0.014777
# Day        0.018254  0.005497  1.000000 -0.003225 -0.001082  0.005187
# killed     0.021252  0.004031 -0.003225  1.000000  0.443326 -0.016710
# Wounded    0.017484  0.003178 -0.001082  0.443326  1.000000  0.016697
# Latitude   0.184924 -0.014777  0.005187 -0.016710  0.016697  1.000000
# Longitude  0.003806 -0.003832 -0.002257 -0.000570  0.000203  0.001409
#
#            Longitude
# Year        0.003806
# Month      -0.003832
# Day        -0.002257
# killed     -0.000570
# Wounded     0.000203
# Latitude    0.001409
# Longitude   1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(terr_df.corr(),annot=True)
plt.show()

# %% [markdown]
# ##Exploratory Data Analysis
# ###Data Visualization

# %% [markdown]
# ###Terrorist affected countries

# %%
#Top 10 affected countries
most_affected_country=terr_df['Country'].value_counts().reset_index().rename(columns={'index':'country','Country':'count'})
top_10=most_affected_country.head(10)
top_10
# Out:
#           country  count
# 0            Iraq  24636
# 1        Pakistan  14368
# 2     Afghanistan  12731
# 3           India  11960
# 4        Colombia   8306
# 5     Philippines   6908
# 6            Peru   6096
# 7     El Salvador   5320
# 8  United Kingdom   5235
# 9          Turkey   4292

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Country'].value_counts()[:15].index,terr_df['Country'].value_counts()[:15].values)
plt.title('most_affected_country')
plt.xlabel('countries')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Least affected country
least_affected_country=most_affected_country.tail(10)
least_affected_country
# Out:
#                  country  count
# 195         Vatican City      1
# 196     Falkland Islands      1
# 197            St. Lucia      1
# 198          North Korea      1
# 199         New Hebrides      1
# 200        International      1
# 201    Wallis and Futuna      1
# 202        South Vietnam      1
# 203              Andorra      1
# 204  Antigua and Barbuda      1

# %% [markdown]
# ###Terrorist affected region

# %%
#Top 10 affected region
most_affected_region=terr_df['Region'].value_counts().reset_index().rename(columns={'index':'region','Region':'count'})
most_affected_region.head(10)
# Out:
#                         region  count
# 0   Middle East & North Africa  50474
# 1                   South Asia  44974
# 2                South America  18978
# 3           Sub-Saharan Africa  17550
# 4               Western Europe  16639
# 5               Southeast Asia  12485
# 6  Central America & Caribbean  10344
# 7               Eastern Europe   5144
# 8                North America   3456
# 9                    East Asia    802

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Region'].value_counts()[:15].index,df['Region'].value_counts()[:15].values)
plt.title('most_affected_region')
plt.xlabel('region')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Least affected region
least_affected_region=most_affected_region.tail(10)
least_affected_region
# Out:
#                          region  count
# 2                 South America  18978
# 3            Sub-Saharan Africa  17550
# 4                Western Europe  16639
# 5                Southeast Asia  12485
# 6   Central America & Caribbean  10344
# 7                Eastern Europe   5144
# 8                 North America   3456
# 9                     East Asia    802
# 10                 Central Asia    563
# 11        Australasia & Oceania    282

# %% [markdown]
# ###Region vs Year

# %%
#Terrorist attacks in region each year
pd.crosstab(terr_df.Year,terr_df.Region).plot(kind='area',figsize=(18,10))
plt.title('Year-wise affected regions')
plt.xlabel('number of attacks')
plt.ylabel('year')
plt.legend({'Middle East & North Africa','South Asia','South America','Sub-Saharan Africa','Western Europe','Southeast Asia','Central America & Caribbean','Eastern Europe','North America','East Asia'})
plt.show()

# %% [markdown]
# ###Terrorist affected cities

# %%
#Top 10 affected cities
most_affected_city=terr_df['City'].value_counts().reset_index().rename(columns={'index':'city','City':'count'})
most_affected_city[:10]
# Out:
#            city  count
# 0       Unknown   9775
# 1       Baghdad   7589
# 2       Karachi   2652
# 3          Lima   2359
# 4         Mosul   2265
# 5       Belfast   2171
# 6      Santiago   1621
# 7     Mogadishu   1581
# 8  San Salvador   1558
# 9      Istanbul   1048

# %%
#Least Affected cities
most_affected_city.tail(10)
# Out:
#                  city  count
# 36664          Mallah      1
# 36665           Nadia      1
# 36666  Nittikai Kulam      1
# 36667       Panchkula      1
# 36668      Ullensaker      1
# 36669          Hotwag      1
# 36670          Ostend      1
# 36671       Balughata      1
# 36672          Jikoyi      1
# 36673        Kubentog      1

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['City'].value_counts()[:15].index,terr_df['City'].value_counts()[:15].values)
plt.title('most_affected_city')
plt.xlabel('city')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Year-wise Terror attacks from 1970-2017

# %%
#Year in which most attacks took place
most_terrific_year=terr_df['Year'].value_counts().reset_index().rename(columns={'index':'year','Year':'count'})
most_terrific_year[:10]
# Out:
#    year  count
# 0  2014  16903
# 1  2015  14965
# 2  2016  13587
# 3  2013  12036
# 4  2017  10900
# 5  2012   8522
# 6  2011   5076
# 7  1992   5071
# 8  2010   4826
# 9  2008   4805

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Year'].value_counts()[:50].index,df['Year'].value_counts()[:50].values)
plt.title('most_affected_year')
plt.xlabel('Year')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Months-wise Terror Attacks

# %%
 #month in which most attacks took place
most_terrific_month=terr_df['Month'].value_counts().reset_index().rename(columns={'index':'month','Month':'count'})
most_terrific_month[:10]
# Out:
#    month  count
# 0      5  16875
# 1      7  16268
# 2      8  15800
# 3     10  15563
# 4      6  15359
# 5      3  15257
# 6      4  15152
# 7      1  14936
# 8     11  14906
# 9      9  14180

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Month'].value_counts()[:15].index,df['Month'].value_counts()[:15].values)
plt.title('most_affected_month')
plt.xlabel('month')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Types of Attacks involved

# %%
#Type of weapons used
most_types_of_attacks=terr_df['Attack_type'].value_counts().reset_index().rename(columns={'index':'weapons','Attack_type':'count'})
most_types_of_attacks[:10]
# Out:
#                                weapons  count
# 0                    Bombing/Explosion  88255
# 1                        Armed Assault  42669
# 2                        Assassination  19312
# 3          Hostage Taking (Kidnapping)  11158
# 4       Facility/Infrastructure Attack  10356
# 5                              Unknown   7276
# 6                      Unarmed Assault   1015
# 7  Hostage Taking (Barricade Incident)    991
# 8                            Hijacking    659

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Attack_type'].value_counts()[:15].index,terr_df['Attack_type'].value_counts()[:15].values)
plt.title('most_attack_type')
plt.xlabel('attack type')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Latitude and Longitude wise terror attacks

# %%
#Lattitudes in which terror attack took place
most_affected_lattitudes=terr_df['Latitude'].value_counts().reset_index().rename(columns={'index':'lattitudes','Latitude':'counts'})
most_affected_lattitudes[:10]
# Out:
#    lattitudes  counts
# 0          33   22208
# 1          34   12477
# 2          31    8012
# 3          36    7913
# 4           6    7793
# 5          32    7403
# 6          13    7316
# 7           0    5911
# 8          35    5461
# 9          24    4723

# %%
#Longitude in which terror attack took place
most_affected_longitude=terr_df['Longitude'].value_counts().reset_index().rename(columns={'index':'longitudes','Longitude':'counts'})
most_affected_longitude[:10]
# Out:
#    longitudes  counts
# 0          44   17978
# 1          43    8153
# 2           0    5577
# 3          35    4774
# 4          71    4353
# 5         -76    4266
# 6          45    4088
# 7          67    3646
# 8          69    3465
# 9         101    3252

# %% [markdown]
# ###Targeted Factors

# %%
#Most targeted population
most_target_factors=terr_df['Target'].value_counts().reset_index().rename(columns={'index':'factors','Target':'count'})
most_target_factors[:10]
# Out:
#          factors  count
# 0      Civilians   6461
# 1        Unknown   5918
# 2       Soldiers   3157
# 3         Patrol   2942
# 4     Checkpoint   2905
# 5        Vehicle   2785
# 6       Officers   1787
# 7        Village   1679
# 8  Military Unit   1533
# 9            Bus   1335

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Target'].value_counts()[:15].index,df['Target'].value_counts()[:15].values)
plt.title('most target factor')
plt.xlabel('target')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Most targeted sub-population
sub_targets=df['targsubtype1_txt'].value_counts().reset_index().rename(columns={'index':'factors','targsubtype1_txt':'count'})
sub_targets[:10]
# Out:
#                                              factors  count
# 0                       Unnamed Civilian/Unspecified  11596
# 1                    Police Security Forces/Officers  11178
# 2                        Military Unit/Patrol/Convoy   8277
# 3  Military Personnel (soldiers, troops, officers...   7963
# 4  Government Personnel (excluding police, military)   6610
# 5                           Village/City/Town/Suburb   6542
# 6  Politician or Political Party Movement/Meeting...   6306
# 7    Police Building (headquarters, station, school)   5907
# 8      Military Barracks/Base/Headquarters/Checkpost   5211
# 9     Police Patrol (including vehicles and convoys)   5105

# %% [markdown]
# ###Weapons Used

# %%
#Most used weapons
most_often_used_weapons=df['weaptype1_txt'].value_counts().reset_index().rename(columns={'index':'weapons','weaptype1_txt':'count'})
most_often_used_weapons[:10]
# Out:
#                                              weapons  count
# 0                                         Explosives  92426
# 1                                           Firearms  58524
# 2                                            Unknown  15157
# 3                                         Incendiary  11135
# 4                                              Melee   3655
# 5                                           Chemical    321
# 6                                 Sabotage Equipment    141
# 7  Vehicle (not to include vehicle-borne explosiv...    136
# 8                                              Other    114
# 9                                         Biological     35

# %%
plt.figure(figsize=(10,5))
sns.barplot(terr_df['Weapon_type'].value_counts()[:15].index,terr_df['Weapon_type'].value_counts()[:15].values)
plt.title('most used weapon')
plt.xlabel('weapon')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Region Vs. Weapon

# %%
plt.subplots(figsize = (20,10))
sns.countplot(x="Region", hue ='Weapon_type', data = terr_df,palette = "Set1")
plt.title('Region Vs. Weapon', fontsize = 30)
plt.xticks(rotation=90)
plt.show()

# %%
#Most used sub-weapons
sub_weapons=df['weapsubtype1_txt'].value_counts().reset_index().rename(columns={'index':'sub_weapons','weapsubtype1_txt':'count'})
sub_weapons[:10]
# Out:
#                                  sub_weapons  count
# 0                     Unknown Explosive Type  44980
# 1                           Unknown Gun Type  33137
# 2          Automatic or Semi-Automatic Rifle  17412
# 3                                    Vehicle   9900
# 4  Projectile (rockets, mortars, RPGs, etc.)   9848
# 5                       Other Explosive Type   7304
# 6                                    Handgun   6704
# 7                                    Grenade   5167
# 8                                   Landmine   4251
# 9                                 Arson/Fire   4141

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['weapsubtype1_txt'].value_counts()[:15].index,df['weapsubtype1_txt'].value_counts()[:15].values)
plt.title('most used sub-weapon')
plt.xlabel('weapon')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Region wise Wounded vs Killed

# %%
#Wounded verses Killed people in different regions
plt.subplot(1,2,1)
plt.rcParams["figure.figsize"] = (8,5)
terr_df.groupby(['Region'])['Wounded'].sum().sort_values(ascending=False).plot(kind='bar',colormap='RdBu')
plt.title('Region having wounded people',fontsize=15)
plt.xlabel('Region')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()

plt.subplot(1,2,2)
plt.rcParams["figure.figsize"] = (8,5)
terr_df.groupby(['Region'])['killed'].sum().sort_values(ascending=False).plot(kind='bar',colormap='RdBu')
plt.title('Region having killed people',fontsize=15)
plt.xlabel('Region')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
plt.gcf().set_size_inches(15,5)

# %% [markdown]
# ###Country wise Wounded vs Killed

# %%
#Wounded verses Killed people in different countries
plt.subplot(1,2,1)
plt.rcParams["figure.figsize"] = (8,5)
terr_df.groupby(['Country'])['Wounded'].sum().sort_values(ascending=False).head(10).plot(kind='bar',colormap='rocket')
plt.title('country having wounded people',fontsize=15)
plt.xlabel('country')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()

plt.subplot(1,2,2)
plt.rcParams["figure.figsize"] = (8,5)
terr_df.groupby(['Country'])['killed'].sum().sort_values(ascending=False).head(10).plot(kind='bar',colormap='rocket')
plt.title('country having killed people',fontsize=15)
plt.xlabel('Region')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()
plt.gcf().set_size_inches(15,5)

# %% [markdown]
# ###Terrorist Organizations

# %%
#Top 10 Terrorist Organizations
plt.figure(figsize=(8,5))
sns.barplot(terr_df['Group'].value_counts()[1:11].values,terr_df['Group'].value_counts()[1:11].index,palette='rocket')
plt.title('Top 10 terrorist organization with terror attacks',fontsize=15)
plt.xlabel('Number of attacks')
plt.ylabel('Terrorist group')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###Attacks by Taliban Organization

# %%
#Summary of Taliban Organzation
terr_df_taliban=terr_df[terr_df.Group=='Taliban']

plt.figure(figsize=(8,5))
sns.barplot(terr_df_taliban['Year'].value_counts().index,terr_df_taliban['Year'].value_counts().values,palette='rocket')
plt.title('Terror attacks over the year by taliban',fontsize=15)
plt.xlabel('Year')
plt.ylabel('number of attack')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
terr_df_taliban.groupby(['Year'])['killed'].sum().plot(kind='bar',colormap='RdBu')
plt.title('People killed by taliban over the years',fontsize=15)
plt.xlabel('years')
plt.ylabel('Number of people killed')
plt.xticks(rotation=90)
plt.grid
plt.show()

# %%
top_groups15=df[df['gname'].isin(df['gname'].value_counts()[1:15].index)]
pd.crosstab(top_groups15.iyear,top_groups15.gname).plot(color=sns.color_palette('Paired',10))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %% [markdown]
# ###Success Rate of Terror Attacks

# %%
#Success rate of terrorist
success_in_attacks=df['success'].value_counts().reset_index()
success_in_attacks
# Out:
#    index  success
# 0      1   161632
# 1      0    20059

# %%
df['success'].value_counts().plot(kind='pie',figsize=[10,5],autopct='%1.1f%%')
plt.title("Success rate for terrorists in their activities")
# Out:
# Text(0.5, 1.0, 'Success rate for terrorists in their activities')

# %% [markdown]
# ###Suicidel Rate

# %%
#sucide rate
suicide_rate=df['suicide'].value_counts().reset_index()
suicide_rate[:10]
# Out:
#    index  suicide
# 0      0   175058
# 1      1     6633

# %%
df['suicide'].value_counts().plot(kind='pie',figsize=[10,5],autopct='%1.1f%%')
plt.title("Suicidal attacks")
# Out:
# Text(0.5, 1.0, 'Suicidal attacks')

# %% [markdown]
# #**Conclusion**

# %%
#SUMMARY OF TERRORIST DATA FRAME

print(f'Country with most attacks:',terr_df['Country'].value_counts().idxmax())
print(f'Region with most attacks:',terr_df['Region'].value_counts().idxmax())
print(f'City with most attacks:',terr_df['City'].value_counts().index[1])
print(f'Year with most attacks:',terr_df['Year'].value_counts().idxmax())
print(f'Month with most attacks:',terr_df['Month'].value_counts().idxmax())
print(f'Most used weapons for attacks:',terr_df['Attack_type'].value_counts().idxmax())
print(f'Most targeted factor of attacks:',terr_df['Target'].value_counts().idxmax())
print("Group with the most attacks:",terr_df['Group'].value_counts().index[1])
# Out:
# Country with most attacks: Iraq
# Region with most attacks: Middle East & North Africa
# City with most attacks: Baghdad
# Year with most attacks: 2014
# Month with most attacks: 5
# Most used weapons for attacks: Bombing/Explosion
# Most targeted factor of attacks: Civilians
# Group with the most attacks: Taliban

# %% [markdown]
# #**Thank** **You**
